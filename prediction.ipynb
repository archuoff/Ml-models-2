# %% [markdown]
# <a href="https://colab.research.google.com/github/archuoff/Ml-models-2/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data= "http://bit.ly/w-data"
data1=pd.read_csv(data)
print(data1)
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
data1.plot(x="Hours",y="Scores",style="o",color='y')
plt.title("prediction")
plt.xlabel("Hours")
plt.xlabel("Scores")
# Out:
# Text(0.5, 0, 'Scores')

# %%
X=data1.iloc[:,:-1].values
Y=data1.iloc[:,1].values
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=20)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
d=LinearRegression()
d.fit(x_train,y_train)
predictions=d.predict(x_test)
m=mean_squared_error(y_test,predictions)
plt.scatter(x_test,y_test,color="r",linewidth=0.3)
plt.plot(x_test,predictions,color="y",linestyle='--')
plt.title("hours vs percentage")
plt.xlabel("Hours")
plt.ylabel("Scores")
print(m)
# Out:
# 35.57857659233007

# %%
d1=pd.DataFrame({'Actual': y_test,"Predicted": predictions})
print(d1)
# Out:
#    Actual  Predicted
# 0      17  12.442587
# 1      21  26.359448
# 2      24  20.395079
# 3      88  92.961570
# 4      76  70.098155
